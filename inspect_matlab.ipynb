# %%
from scipy.io import loadmat
from pprint import pprint
pprint(loadmat("ninaPro/s1/S1_E2_A1.mat"), depth=1)
# for i in loadmat("ninaPro/s1/S1_E2_A1.mat")['restimulus']:
#     print(i)
# Out:
# {'__globals__': [],
#  '__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Thu Jul '
#                b'23 16:00:59 2015',
#  '__version__': '1.0',
#  'acc': array([[-0.06445312,  0.8754883 , -0.49169922],
#        [-0.06445312,  0.8754883 , -0.49169922],
#        [-0.0390625 ,  0.8857422 , -0.5019531 ],
#        ...,
#        [-0.05761719,  0.70947266, -0.7006836 ],
#        [-0.05761719,  0.70947266, -0.7006836 ],
#        [-0.05761719,  0.70947266, -0.7006836 ]], dtype=float32),
#  'age': array([[23]], dtype=uint8),
#  'circumference': array([[24]], dtype=uint8),
#  'emg': array([[-20.,   7., -11., ...,  -4., -14.,  -1.],
#        [ -8., -20., -27., ...,  -7.,   2.,  -8.],
#        [  8.,  18.,  30., ...,   6.,  -9.,   0.],
#        ...,
#        [ -3.,  -2.,  -2., ...,  -1.,  -2.,  -5.],
#        [ -4.,  -2.,  -1., ...,   1.,   2.,   1.],
#        [ -7.,  -1.,   2., ...,  -1.,   0.,  -1.]], dtype=float32),
#  'exercise': array([[1]], dtype=uint8),
# ...

# %%
import pickle
from pprint import pprint
data = pickle.load(open("data/Best_affection_10_emg_rec.p", "rb"))
pprint(len(pickle.load(open("data/Best_affection_10_emg_rec.p", "rb"))), indent=4)
print([i[0] if i[1] else None for i in pickle.load(open("data/Best_affection_10_imu_rec.p", "rb"))])
# Out:
# 137
# ...
